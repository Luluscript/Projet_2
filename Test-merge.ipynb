# %%
import pandas as pd
file_path = r"C:\Users\Lulu\Documents\WCS\Projet_2\tmdb_full.csv"
 # Lire le fichier CSV
df8 = pd.read_csv(file_path, sep=',')
df3 = pd.read_csv("https://datasets.imdbws.com/title.basics.tsv.gz", sep = "\t")
# Out:
# C:\Users\Lulu\AppData\Local\Temp\ipykernel_19824\537434946.py:4: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df8 = pd.read_csv(file_path, sep=',')
# C:\Users\Lulu\AppData\Local\Temp\ipykernel_19824\537434946.py:5: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3 = pd.read_csv("https://datasets.imdbws.com/title.basics.tsv.gz", sep = "\t")

# %%
df_merge = pd.merge(df8,
                df3,
                how="inner",
                left_on='imdb_id',
                right_on='tconst',
                sort = True)

# %%
pd.set_option('display.max_columns', None)
df_merge.head(5)
# Out:
#    adult                     backdrop_path  budget                  genres_x  \
# 0  False                               NaN       0           ['Documentary']
# 1  False  /pfeS2kjgvrjsCaKQ2NCFR22b9aR.jpg       0             ['Animation']
# 2  False  /tXPCJDP3oXJi91TVaxV0CUZdfZc.jpg       0   ['Comedy', 'Animation']
# 3  False                               NaN       0             ['Animation']
# 4  False                               NaN       0  ['Drama', 'Documentary']
#
#                                             homepage     id    imdb_id  \
# 0                                                NaN  16612  tt0000001
# 1  https://www.emilereynaud.fr/index.php/post/Clo...  16613  tt0000002
# 2                                                NaN  88013  tt0000003
# 3  https://www.emilereynaud.fr/index.php/post/Un-...  16622  tt0000004
# 4                                                NaN  16624  tt0000005
#
#   original_language                                           overview  \
# ...

# %%
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308875 entries, 0 to 308874
# Data columns (total 34 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   adult                         308875 non-null  bool
#  1   backdrop_path                 151503 non-null  object
#  2   budget                        308875 non-null  int64
#  3   genres_x                      308875 non-null  object
#  4   homepage                      44147 non-null   object
#  5   id                            308875 non-null  int64
#  6   imdb_id                       308875 non-null  object
#  7   original_language             308875 non-null  object
#  8   original_title                308875 non-null  object
#  9   overview                      281900 non-null  object
#  10  popularity                    308875 non-null  float64
#  11  poster_path                   263649 non-null  object
# ...

# %%
df_merge = df_merge.drop(columns = ['original_title'])

# %%
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308875 entries, 0 to 308874
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   adult                         308875 non-null  bool
#  1   backdrop_path                 151503 non-null  object
#  2   budget                        308875 non-null  int64
#  3   genres_x                      308875 non-null  object
#  4   homepage                      44147 non-null   object
#  5   id                            308875 non-null  int64
#  6   imdb_id                       308875 non-null  object
#  7   original_language             308875 non-null  object
#  8   overview                      281900 non-null  object
#  9   popularity                    308875 non-null  float64
#  10  poster_path                   263649 non-null  object
#  11  production_countries          308875 non-null  object
# ...

# %% [markdown]
# ### TEST de concatenation de colonnes en une seule

# %%
zz = pd.concat([df_merge["primaryTitle"], df_merge["title"]],ignore_index=True)
print(zz)
# Out:
# 0                                           Carmencita
# 1                               Le clown et ses chiens
# 2                                       Pauvre Pierrot
# 3                                          Un bon bock
# 4                                     Blacksmith Scene
#                               ...
# 617745                                       Safeguard
# 617746    Danielle Darrieux : Il est poli d'être gai !
# 617747                        The Talent of the Hornet
# 617748                                           Coven
# 617749                                       Pink Taxi
# Length: 617750, dtype: object

# %% [markdown]
# ## Export en csv

# %%
df_merge.to_csv('imdb_tmdb.csv', index=False)
